# %% [markdown]
# This notebook contains the preprocessing part of the hotels dataset obtained from https://www.kaggle.com/datasets/raj713335/tbo-hotels-dataset this dataset was cleaned and filtered here to only generate embeddings for the indian hotels.

# %%
import pandas as pd

# %%
hotels = pd.read_csv('dataset/hotels.csv', encoding='ISO-8859-1')

# %%
hotels.columns = hotels.columns.str.strip()

# %%
indian_hotels = hotels[hotels['countyName'].str.contains('India', case=False)]
indian_hotels.sample(10)
# Out:
#        countyCode countyName  cityCode                       cityName  \
# 357891         IN      India    105699                       Candolim
# 355521         IN      India    111932       Bhopal,   Madhya Pradesh
# 384114         IN      India    139456  Srinagar,   Jammu and Kashmir
# 350520         IN      India    100263           Ahmedabad,   Gujarat
# 359512         IN      India    127343          Chennai,   Tamil Nadu
# 350801         IN      India    100263           Ahmedabad,   Gujarat
# 375145         IN      India    129044                         Morjim
# 368993         IN      India    121783     Jammu,   Jammu and Kashmir
# 375358         IN      India    129415      Mukteshwar,   Uttarakhand
# 387128         IN      India    148500   Vijayawada,   Andhra Pradesh
#
#         HotelCode                           HotelName HotelRating  \
# 357891    1031065              Silver Sands Hide Away   ThreeStar
# ...

# %%
indian_hotels = indian_hotels.drop(columns=['countyCode', 'countyName', 'cityCode', 'Attractions'])

# %%
del hotels

# %%
indian_hotels.isnull().sum()
# Out:
# cityName               0
# HotelCode              0
# HotelName              0
# HotelRating            0
# Address                2
# Description         3135
# FaxNumber          24348
# HotelFacilities     2995
# Map                  211
# PhoneNumber         9708
# PinCode              383
# HotelWebsiteUrl    12451
# dtype: int64

# %%
indian_hotels = indian_hotels.dropna(subset=['Description'])

# %%
indian_hotels
# Out:
#                      cityName  HotelCode                          HotelName  \
# 350060               Abu Road    1416145                     Hotel Bhagwati
# 350061               Abu Road    1505601               Hotel Royal Heritage
# 350062               Abu Road    1512652                        Hotel Bhumi
# 350063               Abu Road    1524275           Hotel Chandrawati Palace
# 350064               Abu Road    1529822               OYO 3784 Hotel Durga
# ...                       ...        ...                                ...
# 387435  Yercaud,   Tamil Nadu    6188176  Kolaahalam Mainland Resorts & Spa
# 387436  Yercaud,   Tamil Nadu    6188604               Sushmika Resorts Inn
# 387437       Yuksom,   Sikkim    1414698    Hotel Red Palace Hotel & Resort
# 387439     Zirakpur,   Punjab    1016043          Aloft Chandigarh Zirakpur
# 387440     Zirakpur,   Punjab    1134422                     Hotel Staywell
#
# ...

# %%
# indian_hotels['full_text'] = indian_hotels['Description'] + ' ' + indian_hotels['HotelFacilities'].fillna('')

# %%
indian_hotels['full_text'] = indian_hotels['HotelFacilities'].fillna('')

# %%
indian_hotels
# Out:
#                      cityName  HotelCode                          HotelName  \
# 350060               Abu Road    1416145                     Hotel Bhagwati
# 350061               Abu Road    1505601               Hotel Royal Heritage
# 350062               Abu Road    1512652                        Hotel Bhumi
# 350063               Abu Road    1524275           Hotel Chandrawati Palace
# 350064               Abu Road    1529822               OYO 3784 Hotel Durga
# ...                       ...        ...                                ...
# 387435  Yercaud,   Tamil Nadu    6188176  Kolaahalam Mainland Resorts & Spa
# 387436  Yercaud,   Tamil Nadu    6188604               Sushmika Resorts Inn
# 387437       Yuksom,   Sikkim    1414698    Hotel Red Palace Hotel & Resort
# 387439     Zirakpur,   Punjab    1016043          Aloft Chandigarh Zirakpur
# 387440     Zirakpur,   Punjab    1134422                     Hotel Staywell
#
# ...

# %%
from imp import *
indian_hotels['clean_text'] = indian_hotels['full_text'].apply(dataPreprocessing)

# %%
indian_hotels = indian_hotels.drop(columns=['full_text'])

# %%
indian

# %%
indian_hotels.to_csv('dataset/indian_hotels2.csv', index=False)

# %%
indian_hotels = pd.read_csv('dataset/indian_hotels2.csv')
indian_hotels
# Out:
#                     cityName  HotelCode                          HotelName  \
# 0                   Abu Road    1416145                     Hotel Bhagwati
# 1                   Abu Road    1505601               Hotel Royal Heritage
# 2                   Abu Road    1512652                        Hotel Bhumi
# 3                   Abu Road    1524275           Hotel Chandrawati Palace
# 4                   Abu Road    1529822               OYO 3784 Hotel Durga
# ...                      ...        ...                                ...
# 34242  Yercaud,   Tamil Nadu    6188176  Kolaahalam Mainland Resorts & Spa
# 34243  Yercaud,   Tamil Nadu    6188604               Sushmika Resorts Inn
# 34244       Yuksom,   Sikkim    1414698    Hotel Red Palace Hotel & Resort
# 34245     Zirakpur,   Punjab    1016043          Aloft Chandigarh Zirakpur
# 34246     Zirakpur,   Punjab    1134422                     Hotel Staywell
#
# ...

# %%
df = df[df['clean_text'].notnull() & (df['clean_text'].str.strip() != "")]
